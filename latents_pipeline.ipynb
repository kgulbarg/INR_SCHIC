# %%
import os
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

# Checking CUDA availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
data_root = "/home/kgulbarg/thesis/INR_SCHIC/Nagano_Data"
path = "/home/kgulbarg/thesis/INR_SCHIC/mm10.main.nochrM.chrom.sizes"
resolution = 1_000_000
n_bins = {}
LABEL_TO_ID = {"G1": 0, "early_S": 1, "mid_S": 2, "late_S": 3}
cells = []

# %%
# read_chrom_sizes

with open(path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) != 2:
                continue
            chr_name, length = parts[0], int(parts[1])
            max_len = length // resolution
            n_bins[chr_name] = max_len + 1  # include trailing partial

print(n_bins)
print(f'total bins:  {sum(n_bins.values())}')
# Out:
# {'chr1': 198, 'chr2': 183, 'chr3': 161, 'chr4': 157, 'chr5': 153, 'chr6': 150, 'chr7': 153, 'chr8': 132, 'chr9': 125, 'chr10': 131, 'chr11': 123, 'chr12': 122, 'chr13': 121, 'chr14': 126, 'chr15': 105, 'chr16': 99, 'chr17': 96, 'chr18': 91, 'chr19': 62, 'chrX': 172}
# total bins:  2660

# %%
def get_data_prepared(cell_dir):
    # load_cell_contacts_and_normalise    
    coords_list = []
    targets_list = []
    
    # for each of 20 chromosomes (1 - 19 and X)
    for fname in sorted(os.listdir(cell_dir)):

        if not (fname.startswith("chr") and fname.endswith(".txt")):
            continue
        
        chr_name = fname[:-4]  # 'chr16' from 'chr16.txt'
        if chr_name == 'chrY': # no contacts in chrY and not in bin sizes
            continue
        nb = n_bins[chr_name]
    
        fp = os.path.join(cell_dir, fname)
        # header on 0th line: bin1    bin2    count
        df = pd.read_csv(fp, sep=r"\s+", header=0, comment="#")

        # checking for reversed pairs:
        tmp = df[df["bin1"] != df["bin2"]].copy()  # ignore diagonal
        tmp["min"] = np.minimum(tmp["bin1"], tmp["bin2"])
        tmp["max"] = np.maximum(tmp["bin1"], tmp["bin2"])
        tmp["ori"] = np.where(tmp["bin1"] < tmp["bin2"], "ij", "ji")
        
        has_reversed = (tmp.groupby(["min", "max"])["ori"].nunique().eq(2)).any()
        # print("Reversed-order duplicates?", bool(has_reversed))
        if bool(has_reversed):
            print("Reversed-order duplicates?", bool(has_reversed), cell_dir, chr_name)

        # aggregate scattered reads
        df_agg = df.groupby(["bin1", "bin2"], as_index=False)["count"].sum()
    
        arr = df_agg[["bin1","bin2","count"]].to_numpy(int)
        
        b1 = arr[:,0]
        b2 = arr[:,1]
        cnt = arr[:,2]
    
        # normalize bin indices to [-1, 1] - linear scaling
        x = 2.0 * (b1.astype(np.float32) / (nb - 1)) - 1.0
        y = 2.0 * (b2.astype(np.float32) / (nb - 1)) - 1.0
        coords_list.append(np.stack([x, y], axis=1))
    
        # transform contact counts: log(1 + cnt) - non linear transform to stabilize variance
        # OR Anscombe: targets_list.append((2.0*np.sqrt(cnt + 0.375))[:, None])
        targets_list.append(np.log1p(cnt)[:, None])
    
    coords = np.concatenate(coords_list, axis=0).astype(np.float32)
    targets = np.concatenate(targets_list, axis=0).astype(np.float32)

    return coords, targets

# print("coords shape:", coords_i.shape, "targets shape:", targets_i.shape)
# print("coords example (first 5):\n", coords_i[:5])
# print("targets example (first 5):\n", targets_i[:5].ravel())

# %%
def  train_latent(coords, targets):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # print("Using device:", device)
    
    # data -> numpy to torch
    X = torch.from_numpy(coords).to(device)   # shape (N, 2)
    y = torch.from_numpy(targets).to(device)  # shape (N, 1)
    
    # simple feedforward with bottleneck (lesser dim) (embedding layer)
    # currently not using bottleneck
    embedding_dim = 256
    
    class ContactNet(nn.Module):
        def __init__(self, emb_dim):
            super().__init__()
            self.fc1 = nn.Linear(2, 64)
            self.fc2 = nn.Linear(64, 512)
            self.fc3 = nn.Linear(512, emb_dim)
            self.fc4 = nn.Linear(emb_dim, 1)    # predict log(count)
        
        def forward(self, x):
            h_0 = torch.relu(self.fc1(x))
            h_1 = torch.relu(self.fc2(h_0))
            emb = torch.relu(self.fc3(h_1))  # <-- embedding matric: one vector (size 256) per coord-target pair
            out = self.fc4(emb)
            return out, emb
    
    model = ContactNet(embedding_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=7e-4)
    loss_fn = nn.MSELoss()

    # minimal training loop
    for epoch in range(100):  # increase for real training
        optimizer.zero_grad()
        preds, _ = model(X)
        loss = loss_fn(preds, y)
        loss.backward()
        optimizer.step()
        if epoch == 99:
            print(f"epoch {epoch}, loss {loss.item():.4f}")
    
    # after training: get embedding for this cell
    with torch.no_grad():
        _, emb = model(X)
        cell_vector = emb.mean(dim=0)  # average across all coords
        
    return cell_vector.detach().cpu().numpy()

# %%
for label in sorted(os.listdir(data_root)):
    print(f"Started: Making latenet representations for {label} cells.")
    label_dir = os.path.join(data_root, label)
    
    if not os.path.isdir(label_dir) or label not in LABEL_TO_ID:
        continue
    
    for cell in sorted(os.listdir(label_dir)):
        cell_dir = os.path.join(label_dir, cell)
        
        if os.path.isdir(cell_dir):            
            coords, targets = get_data_prepared(cell_dir)
            cell_vector = train_latent(coords, targets)
            latent_path = cell_dir + "_latent.npy"
            np.save(latent_path, cell_vector) # loaded = np.load("cell_vector.npy")
# Out:
# Using device: cuda
# epoch 99, loss 0.0299
# Using device: cuda
# epoch 99, loss 0.0333
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0209
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0422
# Using device: cuda
# epoch 99, loss 0.0206
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0204
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0209
# Using device: cuda
# epoch 99, loss 0.0328
# Using device: cuda
# epoch 99, loss 0.0368
# Using device: cuda
# epoch 99, loss 0.0215
# Using device: cuda
# epoch 99, loss 0.0214
# Using device: cuda
# epoch 99, loss 0.0219
# Using device: cuda
# epoch 99, loss 0.0216
# Using device: cuda
# epoch 99, loss 0.0213
# Using device: cuda
# epoch 99, loss 0.0208
# Using device: cuda
# epoch 99, loss 0.0418
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0163
# Using device: cuda
# epoch 99, loss 0.0382
# Using device: cuda
# epoch 99, loss 0.0170
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0178
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0207
# Using device: cuda
# epoch 99, loss 0.0310
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0204
# Using device: cuda
# epoch 99, loss 0.0197
# Using device: cuda
# epoch 99, loss 0.0203
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0192
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0192
# Using device: cuda
# epoch 99, loss 0.0371
# Using device: cuda
# epoch 99, loss 0.0208
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0192
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0391
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0203
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0296
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0392
# Using device: cuda
# epoch 99, loss 0.0223
# Using device: cuda
# epoch 99, loss 0.0197
# Using device: cuda
# epoch 99, loss 0.0213
# Using device: cuda
# epoch 99, loss 0.0214
# Using device: cuda
# epoch 99, loss 0.0212
# Using device: cuda
# epoch 99, loss 0.0209
# Using device: cuda
# epoch 99, loss 0.0421
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0361
# Using device: cuda
# epoch 99, loss 0.0170
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0171
# Using device: cuda
# epoch 99, loss 0.0433
# Using device: cuda
# epoch 99, loss 0.0177
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0198
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0328
# Using device: cuda
# epoch 99, loss 0.0353
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0177
# Using device: cuda
# epoch 99, loss 0.0453
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0167
# Using device: cuda
# epoch 99, loss 0.0299
# Using device: cuda
# epoch 99, loss 0.0171
# Using device: cuda
# epoch 99, loss 0.0172
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0397
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0172
# Using device: cuda
# epoch 99, loss 0.0400
# Using device: cuda
# epoch 99, loss 0.0167
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0163
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0170
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0389
# Using device: cuda
# epoch 99, loss 0.0331
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0170
# Using device: cuda
# epoch 99, loss 0.0165
# Using device: cuda
# epoch 99, loss 0.0176
# Using device: cuda
# epoch 99, loss 0.0172
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0287
# Using device: cuda
# epoch 99, loss 0.0171
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0333
# Using device: cuda
# epoch 99, loss 0.0171
# Using device: cuda
# epoch 99, loss 0.0170
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0366
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0156
# Using device: cuda
# epoch 99, loss 0.0172
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0354
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0347
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0167
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0374
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0377
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0167
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0385
# Using device: cuda
# epoch 99, loss 0.0172
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0325
# Using device: cuda
# epoch 99, loss 0.0451
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0187
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0387
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0184
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0381
# Using device: cuda
# epoch 99, loss 0.0178
# Using device: cuda
# epoch 99, loss 0.0257
# Using device: cuda
# epoch 99, loss 0.0344
# Using device: cuda
# epoch 99, loss 0.0346
# Using device: cuda
# epoch 99, loss 0.0402
# Using device: cuda
# epoch 99, loss 0.0331
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0299
# Using device: cuda
# epoch 99, loss 0.0397
# Using device: cuda
# epoch 99, loss 0.0365
# Using device: cuda
# epoch 99, loss 0.0465
# Using device: cuda
# epoch 99, loss 0.0411
# Using device: cuda
# epoch 99, loss 0.0344
# Using device: cuda
# epoch 99, loss 0.0425
# Using device: cuda
# epoch 99, loss 0.0329
# Using device: cuda
# epoch 99, loss 0.0373
# Using device: cuda
# epoch 99, loss 0.0345
# Using device: cuda
# epoch 99, loss 0.0389
# Using device: cuda
# epoch 99, loss 0.0398
# Using device: cuda
# epoch 99, loss 0.0339
# Using device: cuda
# epoch 99, loss 0.0393
# Using device: cuda
# epoch 99, loss 0.0345
# Using device: cuda
# epoch 99, loss 0.0312
# Using device: cuda
# epoch 99, loss 0.0386
# Using device: cuda
# epoch 99, loss 0.0339
# Using device: cuda
# epoch 99, loss 0.0388
# Using device: cuda
# epoch 99, loss 0.0350
# Using device: cuda
# epoch 99, loss 0.0389
# Using device: cuda
# epoch 99, loss 0.0383
# Using device: cuda
# epoch 99, loss 0.0339
# Using device: cuda
# epoch 99, loss 0.0401
# Using device: cuda
# epoch 99, loss 0.0400
# Using device: cuda
# epoch 99, loss 0.0315
# Using device: cuda
# epoch 99, loss 0.0333
# Using device: cuda
# epoch 99, loss 0.0372
# Using device: cuda
# epoch 99, loss 0.0357
# Using device: cuda
# epoch 99, loss 0.0402
# Using device: cuda
# epoch 99, loss 0.0433
# Using device: cuda
# epoch 99, loss 0.0417
# Using device: cuda
# epoch 99, loss 0.0400
# Using device: cuda
# epoch 99, loss 0.0436
# Using device: cuda
# epoch 99, loss 0.0425
# Using device: cuda
# epoch 99, loss 0.0393
# Using device: cuda
# epoch 99, loss 0.0411
# Using device: cuda
# epoch 99, loss 0.0399
# Using device: cuda
# epoch 99, loss 0.0438
# Using device: cuda
# epoch 99, loss 0.0396
# Using device: cuda
# epoch 99, loss 0.0444
# Using device: cuda
# epoch 99, loss 0.0402
# Using device: cuda
# epoch 99, loss 0.0423
# Using device: cuda
# epoch 99, loss 0.0423
# Using device: cuda
# epoch 99, loss 0.0439
# Using device: cuda
# epoch 99, loss 0.0422
# Using device: cuda
# epoch 99, loss 0.0454
# Using device: cuda
# epoch 99, loss 0.0440
# Using device: cuda
# epoch 99, loss 0.0457
# Using device: cuda
# epoch 99, loss 0.0441
# Using device: cuda
# epoch 99, loss 0.0402
# Using device: cuda
# epoch 99, loss 0.0370
# Using device: cuda
# epoch 99, loss 0.0389
# Using device: cuda
# epoch 99, loss 0.0422
# Using device: cuda
# epoch 99, loss 0.0406
# Using device: cuda
# epoch 99, loss 0.0432
# Using device: cuda
# epoch 99, loss 0.0395
# Using device: cuda
# epoch 99, loss 0.0386
# Using device: cuda
# epoch 99, loss 0.0378
# Using device: cuda
# epoch 99, loss 0.0415
# Using device: cuda
# epoch 99, loss 0.0411
# Using device: cuda
# epoch 99, loss 0.0350
# Using device: cuda
# epoch 99, loss 0.0417
# Using device: cuda
# epoch 99, loss 0.0433
# Using device: cuda
# epoch 99, loss 0.0417
# Using device: cuda
# epoch 99, loss 0.0378
# Using device: cuda
# epoch 99, loss 0.0426
# Using device: cuda
# epoch 99, loss 0.0434
# Using device: cuda
# epoch 99, loss 0.0410
# Using device: cuda
# epoch 99, loss 0.0431
# Using device: cuda
# epoch 99, loss 0.0418
# Using device: cuda
# epoch 99, loss 0.0201
# Using device: cuda
# epoch 99, loss 0.0382
# Using device: cuda
# epoch 99, loss 0.0409
# Using device: cuda
# epoch 99, loss 0.0387
# Using device: cuda
# epoch 99, loss 0.0432
# Using device: cuda
# epoch 99, loss 0.0418
# Using device: cuda
# epoch 99, loss 0.0398
# Using device: cuda
# epoch 99, loss 0.0425
# Using device: cuda
# epoch 99, loss 0.0338
# Using device: cuda
# epoch 99, loss 0.0409
# Using device: cuda
# epoch 99, loss 0.0399
# Using device: cuda
# epoch 99, loss 0.0376
# Using device: cuda
# epoch 99, loss 0.0343
# Using device: cuda
# epoch 99, loss 0.0413
# Using device: cuda
# epoch 99, loss 0.0408
# Using device: cuda
# epoch 99, loss 0.0407
# Using device: cuda
# epoch 99, loss 0.0431
# Using device: cuda
# epoch 99, loss 0.0421
# Using device: cuda
# epoch 99, loss 0.0432
# Using device: cuda
# epoch 99, loss 0.0356
# Using device: cuda
# epoch 99, loss 0.0431
# Using device: cuda
# epoch 99, loss 0.0504
# Using device: cuda
# epoch 99, loss 0.0455
# Using device: cuda
# epoch 99, loss 0.0282
# Using device: cuda
# epoch 99, loss 0.0432
# Using device: cuda
# epoch 99, loss 0.0454
# Using device: cuda
# epoch 99, loss 0.0357
# Using device: cuda
# epoch 99, loss 0.0419
# Using device: cuda
# epoch 99, loss 0.0444
# Using device: cuda
# epoch 99, loss 0.0412
# Using device: cuda
# epoch 99, loss 0.0417
# Using device: cuda
# epoch 99, loss 0.0201
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0171
# Using device: cuda
# epoch 99, loss 0.0165
# Using device: cuda
# epoch 99, loss 0.0206
# Using device: cuda
# epoch 99, loss 0.0196
# Using device: cuda
# epoch 99, loss 0.0198
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0185
# Using device: cuda
# epoch 99, loss 0.0264
# Using device: cuda
# epoch 99, loss 0.0247
# Using device: cuda
# epoch 99, loss 0.0278
# Using device: cuda
# epoch 99, loss 0.0176
# Using device: cuda
# epoch 99, loss 0.0177
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0237
# Using device: cuda
# epoch 99, loss 0.0273
# Using device: cuda
# epoch 99, loss 0.0286
# Using device: cuda
# epoch 99, loss 0.0285
# Using device: cuda
# epoch 99, loss 0.0281
# Using device: cuda
# epoch 99, loss 0.0284
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0263
# Using device: cuda
# epoch 99, loss 0.0185
# Using device: cuda
# epoch 99, loss 0.0276
# Using device: cuda
# epoch 99, loss 0.0292
# Using device: cuda
# epoch 99, loss 0.0204
# Using device: cuda
# epoch 99, loss 0.0289
# Using device: cuda
# epoch 99, loss 0.0280
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0253
# Using device: cuda
# epoch 99, loss 0.0250
# Using device: cuda
# epoch 99, loss 0.0264
# Using device: cuda
# epoch 99, loss 0.0239
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0259
# Using device: cuda
# epoch 99, loss 0.0251
# Using device: cuda
# epoch 99, loss 0.0249
# Using device: cuda
# epoch 99, loss 0.0252
# Using device: cuda
# epoch 99, loss 0.0250
# Using device: cuda
# epoch 99, loss 0.0247
# Using device: cuda
# epoch 99, loss 0.0239
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0244
# Using device: cuda
# epoch 99, loss 0.0237
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0250
# Using device: cuda
# epoch 99, loss 0.0263
# Using device: cuda
# epoch 99, loss 0.0272
# Using device: cuda
# epoch 99, loss 0.0253
# Using device: cuda
# epoch 99, loss 0.0260
# Using device: cuda
# epoch 99, loss 0.0253
# Using device: cuda
# epoch 99, loss 0.0250
# Using device: cuda
# epoch 99, loss 0.0256
# Using device: cuda
# epoch 99, loss 0.0248
# Using device: cuda
# epoch 99, loss 0.0250
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0250
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0249
# Using device: cuda
# epoch 99, loss 0.0241
# Using device: cuda
# epoch 99, loss 0.0254
# Using device: cuda
# epoch 99, loss 0.0246
# Using device: cuda
# epoch 99, loss 0.0254
# Using device: cuda
# epoch 99, loss 0.0252
# Using device: cuda
# epoch 99, loss 0.0232
# Using device: cuda
# epoch 99, loss 0.0257
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0254
# Using device: cuda
# epoch 99, loss 0.0265
# Using device: cuda
# epoch 99, loss 0.0268
# Using device: cuda
# epoch 99, loss 0.0274
# Using device: cuda
# epoch 99, loss 0.0270
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0263
# Using device: cuda
# epoch 99, loss 0.0255
# Using device: cuda
# epoch 99, loss 0.0265
# Using device: cuda
# epoch 99, loss 0.0263
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0266
# Using device: cuda
# epoch 99, loss 0.0218
# Using device: cuda
# epoch 99, loss 0.0204
# Using device: cuda
# epoch 99, loss 0.0253
# Using device: cuda
# epoch 99, loss 0.0242
# Using device: cuda
# epoch 99, loss 0.0256
# Using device: cuda
# epoch 99, loss 0.0247
# Using device: cuda
# epoch 99, loss 0.0243
# Using device: cuda
# epoch 99, loss 0.0251
# Using device: cuda
# epoch 99, loss 0.0206
# Using device: cuda
# epoch 99, loss 0.0180
# Using device: cuda
# epoch 99, loss 0.0266
# Using device: cuda
# epoch 99, loss 0.0247
# Using device: cuda
# epoch 99, loss 0.0270
# Using device: cuda
# epoch 99, loss 0.0266
# Using device: cuda
# epoch 99, loss 0.0265
# Using device: cuda
# epoch 99, loss 0.0261
# Using device: cuda
# epoch 99, loss 0.0208
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0209
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0206
# Using device: cuda
# epoch 99, loss 0.0184
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0196
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0198
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0211
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0206
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0209
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0215
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0206
# Using device: cuda
# epoch 99, loss 0.0204
# Using device: cuda
# epoch 99, loss 0.0208
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0197
# Using device: cuda
# epoch 99, loss 0.0202
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0203
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0211
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0207
# Using device: cuda
# epoch 99, loss 0.0197
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0180
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0212
# Using device: cuda
# epoch 99, loss 0.0185
# Using device: cuda
# epoch 99, loss 0.0180
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0196
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0185
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0198
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0210
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0187
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0210
# Using device: cuda
# epoch 99, loss 0.0209
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0149
# Using device: cuda
# epoch 99, loss 0.0199
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0178
# Using device: cuda
# epoch 99, loss 0.0184
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0177
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0196
# Using device: cuda
# epoch 99, loss 0.0180
# Using device: cuda
# epoch 99, loss 0.0185
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0198
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0196
# Using device: cuda
# epoch 99, loss 0.0198
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0197
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0207
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0178
# Using device: cuda
# epoch 99, loss 0.0163
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0195
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0188
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0191
# Using device: cuda
# epoch 99, loss 0.0184
# Using device: cuda
# epoch 99, loss 0.0180
# Using device: cuda
# epoch 99, loss 0.0207
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0166
# Using device: cuda
# epoch 99, loss 0.0185
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0204
# Using device: cuda
# epoch 99, loss 0.0203
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0193
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0187
# Using device: cuda
# epoch 99, loss 0.0176
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0190
# Using device: cuda
# epoch 99, loss 0.0213
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0194
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0170
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0196
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0182
# Using device: cuda
# epoch 99, loss 0.0087
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0165
# Using device: cuda
# epoch 99, loss 0.0178
# Using device: cuda
# epoch 99, loss 0.0174
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0177
# Using device: cuda
# epoch 99, loss 0.0175
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0176
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0173
# Using device: cuda
# epoch 99, loss 0.0172
# Using device: cuda
# epoch 99, loss 0.0181
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0178
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0179
# Using device: cuda
# epoch 99, loss 0.0186
# Using device: cuda
# epoch 99, loss 0.0180
# Using device: cuda
# epoch 99, loss 0.0197
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0210
# Using device: cuda
# epoch 99, loss 0.0189
# Using device: cuda
# epoch 99, loss 0.0210
# Using device: cuda
# epoch 99, loss 0.0183
# Using device: cuda
# epoch 99, loss 0.0200
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0116
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0129
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0121
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0110
# Using device: cuda
# epoch 99, loss 0.0129
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0117
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0127
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0122
# Using device: cuda
# epoch 99, loss 0.0131
# Using device: cuda
# epoch 99, loss 0.0131
# Using device: cuda
# epoch 99, loss 0.0131
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0084
# Using device: cuda
# epoch 99, loss 0.0121
# Using device: cuda
# epoch 99, loss 0.0131
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0133
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0132
# Using device: cuda
# epoch 99, loss 0.0133
# Using device: cuda
# epoch 99, loss 0.0133
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0126
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0082
# Using device: cuda
# epoch 99, loss 0.0110
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0090
# Using device: cuda
# epoch 99, loss 0.0123
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0127
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0092
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0106
# Using device: cuda
# epoch 99, loss 0.0107
# Using device: cuda
# epoch 99, loss 0.0132
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0087
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0121
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0093
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0103
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0114
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0129
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0121
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0084
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0125
# Using device: cuda
# epoch 99, loss 0.0116
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0123
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0117
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0107
# Using device: cuda
# epoch 99, loss 0.0103
# Using device: cuda
# epoch 99, loss 0.0106
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0123
# Using device: cuda
# epoch 99, loss 0.0121
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0079
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0107
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0116
# Using device: cuda
# epoch 99, loss 0.0122
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0088
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0125
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0082
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0093
# Using device: cuda
# epoch 99, loss 0.0111
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0079
# Using device: cuda
# epoch 99, loss 0.0093
# Using device: cuda
# epoch 99, loss 0.0110
# Using device: cuda
# epoch 99, loss 0.0090
# Using device: cuda
# epoch 99, loss 0.0107
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0075
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0116
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0092
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0116
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0116
# Using device: cuda
# epoch 99, loss 0.0114
# Using device: cuda
# epoch 99, loss 0.0125
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0095
# Using device: cuda
# epoch 99, loss 0.0095
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0076
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0087
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0090
# Using device: cuda
# epoch 99, loss 0.0117
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0075
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0080
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0106
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0111
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0114
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0149
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0095
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0106
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0111
# Using device: cuda
# epoch 99, loss 0.0125
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0123
# Using device: cuda
# epoch 99, loss 0.0083
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0104
# Using device: cuda
# epoch 99, loss 0.0124
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0126
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0095
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0132
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0149
# Using device: cuda
# epoch 99, loss 0.0079
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0133
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0091
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0106
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0110
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0114
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0131
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0107
# Using device: cuda
# epoch 99, loss 0.0109
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0080
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0161
# Using device: cuda
# epoch 99, loss 0.0167
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0167
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0163
# Using device: cuda
# epoch 99, loss 0.0122
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0129
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0164
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0127
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0064
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0149
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0137
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0091
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0156
# Using device: cuda
# epoch 99, loss 0.0126
# Using device: cuda
# epoch 99, loss 0.0160
# Using device: cuda
# epoch 99, loss 0.0165
# Using device: cuda
# epoch 99, loss 0.0162
# Using device: cuda
# epoch 99, loss 0.0166
# Using device: cuda
# epoch 99, loss 0.0184
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0156
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0156
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0127
# Using device: cuda
# epoch 99, loss 0.0155
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0157
# Using device: cuda
# epoch 99, loss 0.0159
# Using device: cuda
# epoch 99, loss 0.0165
# Using device: cuda
# epoch 99, loss 0.0126
# Using device: cuda
# epoch 99, loss 0.0152
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0132
# Using device: cuda
# epoch 99, loss 0.0113
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0129
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0124
# Using device: cuda
# epoch 99, loss 0.0169
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0130
# Using device: cuda
# epoch 99, loss 0.0115
# Using device: cuda
# epoch 99, loss 0.0126
# Using device: cuda
# epoch 99, loss 0.0111
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0122
# Using device: cuda
# epoch 99, loss 0.0120
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0153
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0163
# Using device: cuda
# epoch 99, loss 0.0128
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0168
# Using device: cuda
# epoch 99, loss 0.0143
# Using device: cuda
# epoch 99, loss 0.0111
# Using device: cuda
# epoch 99, loss 0.0158
# Using device: cuda
# epoch 99, loss 0.0135
# Using device: cuda
# epoch 99, loss 0.0127
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0131
# Using device: cuda
# epoch 99, loss 0.0133
# Using device: cuda
# epoch 99, loss 0.0129
# Using device: cuda
# epoch 99, loss 0.0207
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0119
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0072
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0125
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0134
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0088
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0088
# Using device: cuda
# epoch 99, loss 0.0133
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0140
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0146
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0110
# Using device: cuda
# epoch 99, loss 0.0154
# Using device: cuda
# epoch 99, loss 0.0142
# Using device: cuda
# epoch 99, loss 0.0151
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0092
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0144
# Using device: cuda
# epoch 99, loss 0.0077
# Using device: cuda
# epoch 99, loss 0.0088
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0022
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0095
# Using device: cuda
# epoch 99, loss 0.0104
# Using device: cuda
# epoch 99, loss 0.0058
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0138
# Using device: cuda
# epoch 99, loss 0.0150
# Using device: cuda
# epoch 99, loss 0.0059
# Using device: cuda
# epoch 99, loss 0.0046
# Using device: cuda
# epoch 99, loss 0.0088
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0104
# Using device: cuda
# epoch 99, loss 0.0078
# Using device: cuda
# epoch 99, loss 0.0147
# Using device: cuda
# epoch 99, loss 0.0145
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0106
# Using device: cuda
# epoch 99, loss 0.0086
# Using device: cuda
# epoch 99, loss 0.0148
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0103
# Using device: cuda
# epoch 99, loss 0.0141
# Using device: cuda
# epoch 99, loss 0.0003
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0139
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0105
# Using device: cuda
# epoch 99, loss 0.0107
# Using device: cuda
# epoch 99, loss 0.0127
# Using device: cuda
# epoch 99, loss 0.0108
# Using device: cuda
# epoch 99, loss 0.0090
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0097
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0098
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0112
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0093
# Using device: cuda
# epoch 99, loss 0.0091
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0102
# Using device: cuda
# epoch 99, loss 0.0110
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0104
# Using device: cuda
# epoch 99, loss 0.0136
# Using device: cuda
# epoch 99, loss 0.0100
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0101
# Using device: cuda
# epoch 99, loss 0.0093
# Using device: cuda
# epoch 99, loss 0.0118
# Using device: cuda
# epoch 99, loss 0.0094
# Using device: cuda
# epoch 99, loss 0.0093
# Using device: cuda
# epoch 99, loss 0.0096
# Using device: cuda
# epoch 99, loss 0.0099
# Using device: cuda
# epoch 99, loss 0.0093
